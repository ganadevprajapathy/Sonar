# %%
import os
import cv2
import typing
import imageio
import numpy as np
import tensorflow as tf
tf.config.experimental.set_memory_growth(tf.config.experimental.list_physical_devices('GPU')[0], True)

from keras.callbacks import TensorBoard
from keras.preprocessing.image import ImageDataGenerator

from model import build_generator, build_discriminator
from keras import layers
from keras import mixed_precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
# Out:
# 2024-05-14 11:45:46.764317: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 11:45:46.764349: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 11:45:46.764393: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-14 11:45:46.771618: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-14 11:45:47.479069: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 4090, compute capability 8.9

# %%
# Define the generator model
def build_generator(noise_dim, img_shape, output_channels=1, activation="tanh", alpha=0.2):
    inputs = layers.Input(shape=noise_dim, name="input")

     # Modified Dense layer with new output size
    x = layers.Dense(25 * 128 * 256, use_bias=False)(inputs)

    # Reshape to match the new dense layer output
    x = layers.Reshape((25, 128, 256))(x)

    x = layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha)(x)

    x = layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(alpha)(x)

    # x = layers.Conv2DTranspose(128, (5, 5), strides=(2, 2), padding="same", use_bias=False)(x)
    # x = layers.BatchNormalization()(x)
    # x = layers.LeakyReLU(alpha)(x)

    # x = layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding="same", use_bias=False)(x)
    # x = layers.BatchNormalization()(x)
    # x = layers.LeakyReLU(alpha)(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv2D(output_channels, (5, 5), strides=(1, 1), padding="same", activation=activation, use_bias=False, dtype='float32')(x)
    print(x.shape)
    assert x.shape == (None, img_shape[0], img_shape[1], 1)

    model = tf.keras.Model(inputs=inputs, outputs=x)

    return model

# %%
# Define the discriminator model
def build_discriminator(img_shape, activation='linear', alpha=0.2):
    inputs = layers.Input(shape=img_shape, name="input")

    x = layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', use_bias=False)(inputs)
    x = layers.LeakyReLU(alpha)(x)

    x = layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.LeakyReLU(alpha)(x)

    # x = layers.Conv2D(256, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    # x = layers.LeakyReLU(alpha)(x)

    # x = layers.Conv2D(512, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    # x = layers.LeakyReLU(alpha)(x)

    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Dense(1, activation=activation, dtype='float32')(x)
    print(x.shape)
    
    model = tf.keras.Model(inputs=inputs, outputs=x)

    return model

# %%
# Wasserstein loss for the discriminator
def discriminator_w_loss(pred_real, pred_fake):
    real_loss = tf.reduce_mean(pred_real)
    fake_loss = tf.reduce_mean(pred_fake)
    return fake_loss - real_loss

# %%
# Wasserstein loss for the generator
def generator_w_loss(pred_fake):
    return -tf.reduce_mean(pred_fake)

# %%
class WGAN_GP(tf.keras.models.Model):
    def __init__(
            self, 
            discriminator: tf.keras.models.Model, 
            generator: tf.keras.models.Model, 
            noise_dim: int, 
            discriminator_extra_steps: int=5, 
            gp_weight: typing.Union[float, int]=10.0
        ) -> None:
        super(WGAN_GP, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.noise_dim = noise_dim
        self.discriminator_extra_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(
            self, 
            discriminator_opt: tf.keras.optimizers.Optimizer, 
            generator_opt: tf.keras.optimizers.Optimizer, 
            discriminator_loss: typing.Callable, 
            generator_loss: typing.Callable, 
            **kwargs
        ) -> None:
        super(WGAN_GP, self).compile(**kwargs)
        self.discriminator_opt = discriminator_opt
        self.generator_opt = generator_opt
        self.discriminator_loss = discriminator_loss
        self.generator_loss = generator_loss

    def add_instance_noise(self, x: tf.Tensor, stddev: float=0.1) -> tf.Tensor:
        """ Adds instance noise to the input tensor."""
        noise = tf.random.normal(tf.shape(x), mean=0.0, stddev=stddev, dtype=x.dtype)
        return x + noise

    def gradient_penalty(
            self, 
            real_samples: tf.Tensor, 
            fake_samples: tf.Tensor, 
            discriminator: tf.keras.models.Model
        ) -> tf.Tensor:
        """ Calculates the gradient penalty.

        Gradient penalty is calculated on an interpolated data
        and added to the discriminator loss.
        """
        batch_size = tf.shape(real_samples)[0]

        # Generate random values for epsilon
        epsilon = tf.random.uniform(shape=[batch_size, 1, 1, 1], minval=0, maxval=1)

        # 1. Interpolate between real and fake samples
        interpolated_samples = epsilon * real_samples + ((1 - epsilon) * fake_samples)

        with tf.GradientTape() as tape:
            tape.watch(interpolated_samples)
            # 2. Get the Critic's output for the interpolated image
            logits = discriminator(interpolated_samples, training=True)

        # 3. Calculate the gradients w.r.t to the interpolated image
        gradients = tape.gradient(logits, interpolated_samples)

        # 4. Calculate the L2 norm of the gradients.
        gradients_norm = tf.sqrt(tf.reduce_sum(tf.square(gradients), axis=[1, 2, 3]))

        # 5. Calculate gradient penalty
        gradient_penalty = tf.reduce_mean((gradients_norm - 1.0) ** 2)

        return gradient_penalty

    def train_step(self, real_samples: tf.Tensor) -> typing.Dict[str, float]:
        batch_size = tf.shape(real_samples)[0]
        noise = tf.random.normal([batch_size, self.noise_dim])
        gps = []

        # Step 1. Train the discriminator with both real and fake samples
        # Train the discriminator more often than the generator
        for _ in range(self.discriminator_extra_steps):

            # Step 1. Train the discriminator with both real images and fake images
            with tf.GradientTape() as tape:
                fake_samples = self.generator(noise, training=True)
                pred_real = self.discriminator(real_samples, training=True)
                pred_fake = self.discriminator(fake_samples, training=True)

                # Add instance noise to real and fake samples
                real_samples = self.add_instance_noise(real_samples)
                fake_samples = self.add_instance_noise(fake_samples)

                # Calculate the WGAN-GP gradient penalty
                gp = self.gradient_penalty(real_samples, fake_samples, self.discriminator)
                gps.append(gp)

                # Add gradient penalty to the original discriminator loss 
                disc_loss = self.discriminator_loss(pred_real, pred_fake) + gp * self.gp_weight 

            # Compute discriminator gradients
            grads = tape.gradient(disc_loss, self.discriminator.trainable_variables)

            # Update discriminator weights
            self.discriminator_opt.apply_gradients(zip(grads, self.discriminator.trainable_variables))

        # Step 2. Train the generator
        with tf.GradientTape() as tape:
            fake_samples = self.generator(noise, training=True)
            pred_fake = self.discriminator(fake_samples, training=True)
            gen_loss = self.generator_loss(pred_fake)

        # Compute generator gradients
        grads = tape.gradient(gen_loss, self.generator.trainable_variables)

        # Update generator wieghts
        self.generator_opt.apply_gradients(zip(grads, self.generator.trainable_variables))   

        # Update the metrics.
        # Metrics are configured in `compile()`.
        self.compiled_metrics.update_state(real_samples, fake_samples)

        results = {m.name: m.result() for m in self.metrics}
        results.update({"d_loss": disc_loss, "g_loss": gen_loss, "gp": tf.reduce_mean(gps)})

        return results

# %%
class ResultsCallback(tf.keras.callbacks.Callback):
    """ Callback for generating and saving images during training."""
    def __init__(
            self, 
            noise_dim: int, 
            output_path: str, 
            examples_to_generate: int=16, 
            grid_size: tuple=(4, 4), 
            spacing: int=5, 
            gif_size: tuple=(416, 416), 
            duration: float=0.1, 
            save_model: bool=True
        ) -> None:
        super(ResultsCallback, self).__init__()
        self.seed = tf.random.normal([examples_to_generate, noise_dim])
        self.results = []
        self.output_path = output_path
        self.results_path = output_path + '/results'
        self.grid_size = grid_size
        self.spacing = spacing
        self.gif_size = gif_size
        self.duration = duration
        self.save_model = save_model

        os.makedirs(self.results_path, exist_ok=True)

    def save_plt(self, epoch: int, results: np.ndarray):
        # construct an image from generated images with spacing between them using numpy
        w, h , c = results[0].shape
        # construct grind with self.grid_size
        grid = np.zeros((self.grid_size[0] * w + (self.grid_size[0] - 1) * self.spacing, self.grid_size[1] * h + (self.grid_size[1] - 1) * self.spacing, c), dtype=np.uint8)
        for i in range(self.grid_size[0]):
            for j in range(self.grid_size[1]):
                grid[i * (w + self.spacing):i * (w + self.spacing) + w, j * (h + self.spacing):j * (h + self.spacing) + h] = results[i * self.grid_size[1] + j]

        grid = cv2.cvtColor(grid, cv2.COLOR_RGB2BGR)

        # save the image
        cv2.imwrite(f'{self.results_path}/img_{epoch}.png', grid)

        # save image to memory resized to gif size
        self.results.append(cv2.resize(grid, self.gif_size, interpolation=cv2.INTER_AREA))

    def on_epoch_end(self, epoch: int, logs: dict=None):
        # Define your custom code here that should be executed at the end of each epoch
        predictions = self.model.generator(self.seed, training=False)
        predictions_uint8 = (predictions * 127.5 + 127.5).numpy().astype(np.uint8)
        self.save_plt(epoch, predictions_uint8)

        if self.save_model:
            # save keras model to disk
            models_path = os.path.join(self.output_path, "model")
            os.makedirs(models_path, exist_ok=True)
            self.model.discriminator.save(models_path + "/discriminator.h5")
            self.model.generator.save(models_path + "/generator.h5")

    def on_train_end(self, logs: dict=None):
        # save the results as a gif with imageio

        # Create a list of imageio image objects from the OpenCV images
        # image is in BGR format, convert to RGB format when loading
        imageio_images = [imageio.core.util.Image(image[...,::-1]) for image in self.results]

        # Write the imageio images to a GIF file
        imageio.mimsave(self.results_path + "/output.gif", imageio_images, duration=self.duration)

# %%
class LRSheduler(tf.keras.callbacks.Callback):
    """Learning rate scheduler for WGAN-GP"""
    def __init__(self, decay_epochs: int, tb_callback=None, min_lr: float=0.00001):
        super(LRSheduler, self).__init__()
        self.decay_epochs = decay_epochs
        self.min_lr = min_lr
        self.tb_callback = tb_callback
        self.compiled = False

    def on_epoch_end(self, epoch, logs=None):
        if not self.compiled:
            self.generator_lr = self.model.generator_opt.lr.numpy()
            self.discriminator_lr = self.model.discriminator_opt.lr.numpy()
            self.compiled = True

        if epoch < self.decay_epochs:
            new_g_lr = max(self.generator_lr * (1 - (epoch / self.decay_epochs)), self.min_lr)
            self.model.generator_opt.lr.assign(new_g_lr)
            new_d_lr = max(self.discriminator_lr * (1 - (epoch / self.decay_epochs)), self.min_lr)
            self.model.discriminator_opt.lr.assign(new_d_lr)
            print(f"Learning rate generator: {new_g_lr}, discriminator: {new_d_lr}")

            # Log the learning rate on TensorBoard
            if self.tb_callback is not None:
                writer = self.tb_callback._writers.get('train')  # get the writer from the TensorBoard callback
                with writer.as_default():
                    tf.summary.scalar('generator_lr', data=new_g_lr, step=epoch)
                    tf.summary.scalar('discriminator_lr', data=new_d_lr, step=epoch)
                    writer.flush()

# %%
# Load dataset
# data_dir = r"C:\Users\Ganadev Prajapathy\Documents\Sonar\Model\Data Preparation 2\Labelled_Tiles"
# data_dir = '/content/drive/MyDrive/Colab Notebooks/Sonar/Data Preparation 2/Labelled_Tiles'
model_path = '/home/republic/Documents/Ganadev/Sonar/Outputs/GANs/WGAN/Results1'
# data_dir = '/content/drive/MyDrive/Colab Notebooks/Sonar/TrainingDataset/Labelled_Target'
# For just labelled mines
data_dir = '/home/republic/Documents/Ganadev/Sonar/Datasets/Labelled_Mines'

# %%
batch_size = 128
img_height = 100
img_width = 512

# %%
# Set the input shape and size for the generator and discriminator
img_shape = (img_height, img_width, 1) # The shape of the input image, input to the discriminator
noise_dim = 128 # The dimension of the noise vector, input to the generator

# %%
# Define your data generator
datagen = ImageDataGenerator(
    preprocessing_function=lambda x: (x / 127.5) - 1.0,  # Normalize image pixel values to [-1, 1]
    horizontal_flip=True  # Data augmentation
)

# %%
# Create a generator that yields batches of images
train_generator = datagen.flow_from_directory(
    directory=data_dir,  # Path to directory containing images
    target_size=img_shape[:2],  # Size of images (height, width)
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode=None,  # Do not use labels
    shuffle=True,  # Shuffle the data
)
# Out:
# Found 115 images belonging to 1 classes.

# %%
generator = build_generator(noise_dim, img_shape)
generator.summary()
# Out:
# (None, 100, 512, 1)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 128)]             0
#
#  dense (Dense)               (None, 819200)            104857600
#
#  reshape (Reshape)           (None, 25, 128, 256)      0
#
#  conv2d_transpose (Conv2DTr  (None, 50, 256, 128)      819200
#  anspose)
#
#  batch_normalization (Batch  (None, 50, 256, 128)      512
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 50, 256, 128)      0
#
#  conv2d_transpose_1 (Conv2D  (None, 100, 512, 64)      204800
#  Transpose)
#
#  batch_normalization_1 (Bat  (None, 100, 512, 64)      256
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 100, 512, 64)      0
#
#  dropout (Dropout)           (None, 100, 512, 64)      0
#
#  conv2d (Conv2D)             (None, 100, 512, 1)       1600
#
# =================================================================
# Total params: 105883968 (403.92 MB)
# Trainable params: 105883584 (403.91 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# 2024-05-14 11:45:48.421048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21970 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:68:00.0, compute capability: 8.9

# %%
discriminator = build_discriminator(img_shape)
discriminator.summary()
# Out:
# (None, 1)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 100, 512, 1)]     0
#
#  conv2d_1 (Conv2D)           (None, 50, 256, 64)       1600
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 50, 256, 64)       0
#
#  conv2d_2 (Conv2D)           (None, 25, 128, 128)      204800
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 25, 128, 128)      0
#
#  flatten (Flatten)           (None, 409600)            0
#
#  dropout_1 (Dropout)         (None, 409600)            0
#
#  dense_1 (Dense)             (None, 1)                 409601
#
# =================================================================
# Total params: 616001 (2.35 MB)
# Trainable params: 616001 (2.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
generator_optimizer = tf.keras.optimizers.Adam(0.0001, beta_1=0.5, beta_2=0.9)
discriminator_optimizer = tf.keras.optimizers.Adam(0.0001, beta_1=0.5, beta_2=0.9)

# %%
callback = ResultsCallback(noise_dim=noise_dim, output_path=model_path, duration=0.04)
tb_callback = TensorBoard(model_path + '/logs')
lr_scheduler = LRSheduler(decay_epochs=500, tb_callback=tb_callback, min_lr=0.00002)

# %%
gan = WGAN_GP(discriminator, generator, noise_dim, discriminator_extra_steps=5)
gan.compile(discriminator_optimizer, generator_optimizer, discriminator_w_loss, generator_w_loss, run_eagerly=False)

# %%
gan.fit(train_generator, epochs=1000, callbacks=[callback, tb_callback, lr_scheduler])
# Out:
# Epoch 1/500
# 2024-05-14 11:45:53.138621: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2024-05-14 11:45:56.699686: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ac5dd94c1e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-14 11:45:56.699714: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-05-14 11:45:56.704180: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-14 11:45:56.801548: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 [==============================] - ETA: 0s - d_loss: -4.2981 - g_loss: 4.4523 - gp: 0.7201WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /home/republic/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Learning rate generator: 9.999999747378752e-05, discriminator: 9.999999747378752e-05
# 1/1 [==============================] - 16s 16s/step - d_loss: -4.2981 - g_loss: 4.4523 - gp: 0.7201
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - d_loss: -44.0942 - g_loss: 15.6414 - gp: 0.6106WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.979999747883995e-05, discriminator: 9.979999747883995e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -44.0942 - g_loss: 15.6414 - gp: 0.6106
# Epoch 3/500
# 1/1 [==============================] - ETA: 0s - d_loss: -122.8209 - g_loss: 34.6734 - gp: 0.2790WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.959999748389237e-05, discriminator: 9.959999748389237e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -122.8209 - g_loss: 34.6734 - gp: 0.2790
# Epoch 4/500
# 1/1 [==============================] - ETA: 0s - d_loss: -237.9972 - g_loss: 61.4030 - gp: 0.0327WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.93999974889448e-05, discriminator: 9.93999974889448e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -237.9972 - g_loss: 61.4030 - gp: 0.0327
# Epoch 5/500
# 1/1 [==============================] - ETA: 0s - d_loss: -366.8489 - g_loss: 82.9042 - gp: 0.6237WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.919999749399722e-05, discriminator: 9.919999749399722e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -366.8489 - g_loss: 82.9042 - gp: 0.6237
# Epoch 6/500
# 1/1 [==============================] - ETA: 0s - d_loss: -478.7235 - g_loss: 83.4435 - gp: 2.8215WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.899999749904965e-05, discriminator: 9.899999749904965e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -478.7235 - g_loss: 83.4435 - gp: 2.8215
# Epoch 7/500
# 1/1 [==============================] - ETA: 0s - d_loss: -573.1917 - g_loss: 89.8426 - gp: 6.9901WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.879999750410206e-05, discriminator: 9.879999750410206e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -573.1917 - g_loss: 89.8426 - gp: 6.9901
# Epoch 8/500
# 1/1 [==============================] - ETA: 0s - d_loss: -676.1451 - g_loss: 133.8553 - gp: 12.9586WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.85999975091545e-05, discriminator: 9.85999975091545e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -676.1451 - g_loss: 133.8553 - gp: 12.9586
# Epoch 9/500
# 1/1 [==============================] - ETA: 0s - d_loss: -777.1982 - g_loss: 211.7144 - gp: 18.9323WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.839999751420691e-05, discriminator: 9.839999751420691e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -777.1982 - g_loss: 211.7144 - gp: 18.9323
# Epoch 10/500
# 1/1 [==============================] - ETA: 0s - d_loss: -860.8549 - g_loss: 342.2517 - gp: 26.3744WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.819999751925935e-05, discriminator: 9.819999751925935e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -860.8549 - g_loss: 342.2517 - gp: 26.3744
# Epoch 11/500
# 1/1 [==============================] - ETA: 0s - d_loss: -975.8773 - g_loss: 512.5748 - gp: 35.5162WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 9.799999752431176e-05, discriminator: 9.799999752431176e-05
# 1/1 [==============================] - 2s 2s/step - d_loss:
-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -7.3099 - g_loss: 197.2286 - gp: 1.8451
# Epoch 53/500
# 1/1 [==============================] - ETA: 0s - d_loss: -3.8971 - g_loss: 170.4303 - gp: 1.6586WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.959999773651361e-05, discriminator: 8.959999773651361e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -3.8971 - g_loss: 170.4303 - gp: 1.6586
# Epoch 54/500
# 1/1 [==============================] - ETA: 0s - d_loss: -4.1129 - g_loss: 141.3186 - gp: 1.3869WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.939999774156605e-05, discriminator: 8.939999774156605e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.1129 - g_loss: 141.3186 - gp: 1.3869
# Epoch 55/500
# 1/1 [==============================] - ETA: 0s - d_loss: -2.7740 - g_loss: 146.4231 - gp: 1.2430WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.919999774661846e-05, discriminator: 8.919999774661846e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -2.7740 - g_loss: 146.4231 - gp: 1.2430
# Epoch 56/500
# 1/1 [==============================] - ETA: 0s - d_loss: -3.3523 - g_loss: 127.4151 - gp: 1.1125WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.89999977516709e-05, discriminator: 8.89999977516709e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -3.3523 - g_loss: 127.4151 - gp: 1.1125
# Epoch 57/500
# 1/1 [==============================] - ETA: 0s - d_loss: -2.1971 - g_loss: 115.3451 - gp: 1.0048WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.879999775672331e-05, discriminator: 8.879999775672331e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -2.1971 - g_loss: 115.3451 - gp: 1.0048
# Epoch 58/500
# 1/1 [==============================] - ETA: 0s - d_loss: -1.7658 - g_loss: 98.2872 - gp: 0.8817WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.859999776177574e-05, discriminator: 8.859999776177574e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -1.7658 - g_loss: 98.2872 - gp: 0.8817
# Epoch 59/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.4030 - g_loss: 110.7106 - gp: 0.8158WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.839999776682816e-05, discriminator: 8.839999776682816e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.4030 - g_loss: 110.7106 - gp: 0.8158
# Epoch 60/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.4141 - g_loss: 98.0190 - gp: 0.7119WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.81999977718806e-05, discriminator: 8.81999977718806e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.4141 - g_loss: 98.0190 - gp: 0.7119
# Epoch 61/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.0401 - g_loss: 87.4517 - gp: 0.6264WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.799999777693301e-05, discriminator: 8.799999777693301e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.0401 - g_loss: 87.4517 - gp: 0.6264
# Epoch 62/500
# 1/1 [==============================] - ETA: 0s - d_loss: 0.0803 - g_loss: 66.2854 - gp: 0.5487WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.779999778198544e-05, discriminator: 8.779999778198544e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: 0.0803 - g_loss: 66.2854 - gp: 0.5487
# Epoch 63/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.1316 - g_loss: 87.6332 - gp: 0.5192WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.759999778703786e-05, discriminator: 8.759999778703786e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.1316 - g_loss: 87.6332 - gp: 0.5192
# Epoch 64/500
# 1/1 [==============================] - ETA: 0s - d_loss: 1.0193 - g_loss: 72.5189 - gp: 0.4353WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.739999779209029e-05, discriminator: 8.739999779209029e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: 1.0193 - g_loss: 72.5189 - gp: 0.4353
# Epoch 65/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.2475 - g_loss: 73.3687 - gp: 0.3913WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.719999779714271e-05, discriminator: 8.719999779714271e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.2475 - g_loss: 73.3687 - gp: 0.3913
# Epoch 66/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.2249 - g_loss: 21.8604 - gp: 0.3678WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.699999780219514e-05, discriminator: 8.699999780219514e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.2249 - g_loss: 21.8604 - gp: 0.3678
# Epoch 67/500
# 1/1 [==============================] - ETA: 0s - d_loss: 0.8437 - g_loss: 115.3572 - gp: 0.3845WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.679999780724756e-05, discriminator: 8.679999780724756e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: 0.8437 - g_loss: 115.3572 - gp: 0.3845
# Epoch 68/500
# 1/1 [==============================] - ETA: 0s - d_loss: 0.8643 - g_loss: -12.6945 - gp: 0.2683WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.659999781229999e-05, discriminator: 8.659999781229999e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: 0.8643 - g_loss: -12.6945 - gp: 0.2683
# Epoch 69/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.3960 - g_loss: 149.5251 - gp: 0.2975WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.639999781735241e-05, discriminator: 8.639999781735241e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.3960 - g_loss: 149.5251 - gp: 0.2975
# Epoch 70/500
# 1/1 [==============================] - ETA: 0s - d_loss: -0.2102 - g_loss: -23.7102 - gp: 0.2445WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.619999782240484e-05, discriminator: 8.619999782240484e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -0.2102 - g_loss: -23.7102 - gp: 0.2445
# Epoch 71/500
# 1/1 [==============================] - ETA: 0s - d_loss: -2.2299 - g_loss: 48.0532 - gp: 0.1727WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.599999782745726e-05, discriminator: 8.599999782745726e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -2.2299 - g_loss: 48.0532 - gp: 0.1727
# Epoch 72/500
# 1/1 [==============================] - ETA: 0s - d_loss: 0.2720 - g_loss: 64.4520 - gp: 0.1774WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.579999783250969e-05, discriminator: 8.579999783250969e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: 0.2720 - g_loss: 64.4520 - gp: 0.1774
# Epoch 73/500
# 1/1 [==============================] - ETA: 0s - d_loss: -1.6756 - g_loss: -54.9267 - gp: 0.1554WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 8.559999783756211e-05, discriminator: 8.559999783756211e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -1.6756 - g_loss: -54.9267 - gp: 0.1554
# Epoch 74/500
# 1/1 [==============================] - ETA: 0s - d_loss: -2.1109 - g_loss: 117.4977 - gp: 0.1423WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ...
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.4567 - g_loss: -28.4341 - gp: 0.0349
# Epoch 475/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.8558 - g_loss: -76.6800 - gp: 0.0518WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.8558 - g_loss: -76.6800 - gp: 0.0518
# Epoch 476/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.2237 - g_loss: -110.5775 - gp: 0.1117WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.2237 - g_loss: -110.5775 - gp: 0.1117
# Epoch 477/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.8635 - g_loss: -120.8826 - gp: 0.1621WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.8635 - g_loss: -120.8826 - gp: 0.1621
# Epoch 478/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.0119 - g_loss: -90.3282 - gp: 0.1146WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.0119 - g_loss: -90.3282 - gp: 0.1146
# Epoch 479/500
# 1/1 [==============================] - ETA: 0s - d_loss: -4.3999 - g_loss: -67.7628 - gp: 0.0681WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.3999 - g_loss: -67.7628 - gp: 0.0681
# Epoch 480/500
# 1/1 [==============================] - ETA: 0s - d_loss: -2.9716 - g_loss: -15.3452 - gp: 0.0315WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -2.9716 - g_loss: -15.3452 - gp: 0.0315
# Epoch 481/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.1867 - g_loss: 41.3588 - gp: 0.0196WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.1867 - g_loss: 41.3588 - gp: 0.0196
# Epoch 482/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.0053 - g_loss: 88.6459 - gp: 0.0338WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.0053 - g_loss: 88.6459 - gp: 0.0338
# Epoch 483/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.4786 - g_loss: 85.5858 - gp: 0.0533WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.4786 - g_loss: 85.5858 - gp: 0.0533
# Epoch 484/500
# 1/1 [==============================] - ETA: 0s - d_loss: -4.4480 - g_loss: 50.7002 - gp: 0.0353WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.4480 - g_loss: 50.7002 - gp: 0.0353
# Epoch 485/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.1017 - g_loss: -0.3938 - gp: 0.0211WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.1017 - g_loss: -0.3938 - gp: 0.0211
# Epoch 486/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.8310 - g_loss: -55.9170 - gp: 0.0278WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.8310 - g_loss: -55.9170 - gp: 0.0278
# Epoch 487/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.7825 - g_loss: -93.9875 - gp: 0.0698WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.7825 - g_loss: -93.9875 - gp: 0.0698
# Epoch 488/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.6482 - g_loss: -112.5155 - gp: 0.1165WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.6482 - g_loss: -112.5155 - gp: 0.1165
# Epoch 489/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.0481 - g_loss: -94.2697 - gp: 0.1115WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.0481 - g_loss: -94.2697 - gp: 0.1115
# Epoch 490/500
# 1/1 [==============================] - ETA: 0s - d_loss: -3.5718 - g_loss: -46.8005 - gp: 0.0550WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -3.5718 - g_loss: -46.8005 - gp: 0.0550
# Epoch 491/500
# 1/1 [==============================] - ETA: 0s - d_loss: -4.5269 - g_loss: -13.3448 - gp: 0.0268WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.5269 - g_loss: -13.3448 - gp: 0.0268
# Epoch 492/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.6274 - g_loss: 35.3884 - gp: 0.0179WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.6274 - g_loss: 35.3884 - gp: 0.0179
# Epoch 493/500
# 1/1 [==============================] - ETA: 0s - d_loss: -7.9444 - g_loss: 78.1486 - gp: 0.0284WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -7.9444 - g_loss: 78.1486 - gp: 0.0284
# Epoch 494/500
# 1/1 [==============================] - ETA: 0s - d_loss: -7.0681 - g_loss: 93.1128 - gp: 0.0434WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -7.0681 - g_loss: 93.1128 - gp: 0.0434
# Epoch 495/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.0954 - g_loss: 59.4604 - gp: 0.0400WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.0954 - g_loss: 59.4604 - gp: 0.0400
# Epoch 496/500
# 1/1 [==============================] - ETA: 0s - d_loss: -3.4907 - g_loss: 24.3462 - gp: 0.0228WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -3.4907 - g_loss: 24.3462 - gp: 0.0228
# Epoch 497/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.2554 - g_loss: -34.2809 - gp: 0.0281WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.2554 - g_loss: -34.2809 - gp: 0.0281
# Epoch 498/500
# 1/1 [==============================] - ETA: 0s - d_loss: -5.1236 - g_loss: -85.1533 - gp: 0.0559WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -5.1236 - g_loss: -85.1533 - gp: 0.0559
# Epoch 499/500
# 1/1 [==============================] - ETA: 0s - d_loss: -6.7397 - g_loss: -111.5652 - gp: 0.1067WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -6.7397 - g_loss: -111.5652 - gp: 0.1067
# Epoch 500/500
# 1/1 [==============================] - ETA: 0s - d_loss: -4.1129 - g_loss: -106.4243 - gp: 0.1114WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Learning rate generator: 2e-05, discriminator: 2e-05
# 1/1 [==============================] - 2s 2s/step - d_loss: -4.1129 - g_loss: -106.4243 - gp: 0.1114
